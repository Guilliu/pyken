# %% [markdown]
# En este notebook vemos como desarrollar un modelo usando el `parceling` como método para la inferencia de denegados

# %% [markdown]
# <span style='color:blue'>Importamos los módulos

# %%
import numpy as np, pandas as pd, pyken as pyk

# %% [markdown]
# <span style='color:blue'>Cargamos el dataset

# %%
df = pd.read_csv('hmeq.csv')
print('El dataset tiene {} filas y {} columnas (incluyendo el target)'.format(df.shape[0], df.shape[1]))
# Out:
# El dataset tiene 5960 filas y 13 columnas (incluyendo el target)

# %% [markdown]
# <span style='color:blue'>Ponemos el nombre de las columnas en minúsculas, renombramos el target como `target_original` y añadimos una columna de tipo id

# %%
df.columns = ['target_original'] + [col.lower() for col in list(df.columns[1:])]
df.insert(0, 'id', [str(i).zfill(4) for i in range(1, len(df)+1)])
df.head()
# Out:
#      id  target_original  loan  mortdue     value   reason     job   yoj  \
# 0  0001                1  1100  25860.0   39025.0  HomeImp   Other  10.5
# 1  0002                1  1300  70053.0   68400.0  HomeImp   Other   7.0
# 2  0003                1  1500  13500.0   16700.0  HomeImp   Other   4.0
# 3  0004                1  1500      NaN       NaN      NaN     NaN   NaN
# 4  0005                0  1700  97800.0  112000.0  HomeImp  Office   3.0
#
#    derog  delinq       clage  ninq  clno  debtinc
# 0    0.0     0.0   94.366667   1.0   9.0      NaN
# 1    0.0     2.0  121.833333   0.0  14.0      NaN
# 2    0.0     0.0  149.466667   1.0  10.0      NaN
# 3    NaN     NaN         NaN   NaN   NaN      NaN
# 4    0.0     0.0   93.333333   0.0  14.0      NaN

# %% [markdown]
# <span style='color:blue'>Generamos los denegados aleatoriamente (esto no debería ser así porque en general los denegados tienen un peor pérfil... pero es un ejemplo) marcamos como denegados al 25%

# %%
mask_rejected = np.array([True]*round(len(df)*0.75)+[False]*(len(df)-round(len(df)*0.75)))
np.random.seed(123) # Importante fijar semilla para que sea replicable
np.random.shuffle(mask_rejected)
df['decision'] = np.where(mask_rejected, 'aprobado', 'rechazado')
df['target'] = np.where(mask_rejected, df['target_original'], -3)
df.head()
# Out:
#      id  target_original  loan  mortdue     value   reason     job   yoj  \
# 0  0001                1  1100  25860.0   39025.0  HomeImp   Other  10.5
# 1  0002                1  1300  70053.0   68400.0  HomeImp   Other   7.0
# 2  0003                1  1500  13500.0   16700.0  HomeImp   Other   4.0
# 3  0004                1  1500      NaN       NaN      NaN     NaN   NaN
# 4  0005                0  1700  97800.0  112000.0  HomeImp  Office   3.0
#
#    derog  delinq       clage  ninq  clno  debtinc   decision  target
# 0    0.0     0.0   94.366667   1.0   9.0      NaN   aprobado       1
# 1    0.0     2.0  121.833333   0.0  14.0      NaN   aprobado       1
# 2    0.0     0.0  149.466667   1.0  10.0      NaN   aprobado       1
# 3    NaN     NaN         NaN   NaN   NaN      NaN   aprobado       1
# 4    0.0     0.0   93.333333   0.0  14.0      NaN  rechazado      -3

# %% [markdown]
# <span style='color:blue'>Vemos la distribución de denegados, buenos y malos que tenemos

# %%
pyk.proc_freq(df, 'target').to_dict()['frequency']
# Out:
# {-3: 1490, 0: 3567, 1: 903}

# %% [markdown]
# <span style='color:blue'>Lo primero es sacar una scorecard *solo con aceptados*

# %%
df_aceptados = df[df.decision == 'aprobado']
pyk.proc_freq(df_aceptados, 'target').to_dict()['frequency']
# Out:
# {0: 3567, 1: 903}

# %%
X, y = df_aceptados.drop('target', axis=1), df_aceptados.target.values

# %% [markdown]
# <span style='color:blue'>Excluimos las variables que no se pueden usar para el desarollo y la `debtinc` por ser demasiado discriminante

# %%
modelo_aceptados = pyk.autoscorecard(excluded_vars=['id', 'target_original', 'decision', 'debtinc']).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Variables no agrupadas: ['reason', 'job']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Cuidado, has puesto un valor numero máximo de iteraciones (12) superior al número de variables candidatas (9)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Step 01 | Time - 0:00:00.363279 | p-value = 8.86e-68 | Gini train = 33.58% | Gini test = 32.99% ---> Feature selected: delinq
# Step 02 | Time - 0:00:00.449691 | p-value = 7.62e-34 | Gini train = 51.49% | Gini test = 45.58% ---> Feature selected: clage
# Step 03 | Time - 0:00:00.441126 | p-value = 1.18e-29 | Gini train = 56.77% | Gini test = 49.32% ---> Feature selected: derog
# Step 04 | Time - 0:00:00.461900 | p-value = 5.19e-27 | Gini train = 63.33% | Gini test = 54.21% ---> Feature selected: value
# Step 05 | Time - 0:00:00.468091 | p-value = 1.53e-18 | Gini train = 66.02% | Gini test = 56.16% ---> Feature selected: loan
# Step 06 | Time - 0:00:00.427886 | p-value = 4.84e-14 | Gini train = 68.26% | Gini test = 56.73% ---> Feature selected: ninq
# Step 07 | Time - 0:00:00.561512 | p-value = 2.40e-10 | Gini train = 69.75% | Gini test = 59.73% ---> Feature selected: yoj
# Step 08 | Time - 0:00:00.537812 | p-value = 9.10e-07 | Gini train = 70.80% | Gini test = 60.95% ---> Feature selected: clno
# Step 09 | Time - 0:00:00.448661 | p-value = 2.83e-03 | Gini train = 71.20% | Gini test = 60.86% ---> Feature selected: mortdue
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['delinq', 'clage', 'derog', 'value', 'loan', 'ninq', 'yoj', 'clno', 'mortdue']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 56.33% de KS y un 71.20% de Gini en la muestra de desarrollo
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 47.30% de KS y un 60.86% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>Con esta scorecard de aceptados vamos a *inferir* cual hubiera sido el target de los denegados

# %%
prediction = modelo_aceptados.transform(df, id_columns=['id'])[['id', 'scorecardpoints']]
df2 = df.merge(prediction.rename(columns={'scorecardpoints': 'scorecardpoints_acep'}), how='left', on='id')
df2.head()
# Out:
#      id  target_original  loan  mortdue     value   reason     job   yoj  \
# 0  0001                1  1100  25860.0   39025.0  HomeImp   Other  10.5
# 1  0002                1  1300  70053.0   68400.0  HomeImp   Other   7.0
# 2  0003                1  1500  13500.0   16700.0  HomeImp   Other   4.0
# 3  0004                1  1500      NaN       NaN      NaN     NaN   NaN
# 4  0005                0  1700  97800.0  112000.0  HomeImp  Office   3.0
#
#    derog  delinq       clage  ninq  clno  debtinc   decision  target  \
# 0    0.0     0.0   94.366667   1.0   9.0      NaN   aprobado       1
# 1    0.0     2.0  121.833333   0.0  14.0      NaN   aprobado       1
# 2    0.0     0.0  149.466667   1.0  10.0      NaN   aprobado       1
# 3    NaN     NaN         NaN   NaN   NaN      NaN   aprobado       1
# 4    0.0     0.0   93.333333   0.0  14.0      NaN  rechazado      -3
#
#    scorecardpoints_acep
# 0                 470.0
# 1                 493.0
# 2                 496.0
# 3                 440.0
# 4                 522.0

# %% [markdown]
# <span style='color:blue'>Aplicamos el *parceling*. Más información en: https://blogs.sas.com/content/sasla/2020/11/12/sommelier-de-riesgo-entrega-8-riesgo-de-credito-tecnicas-de-inferencia-de-denegados/

# %%
df3, c = pyk.parceling(df2, randomly=False)
df3.head()
# Out:
# Breakpoints: [310.0, 332.07, 354.13, 376.2, 398.27, 420.33, 442.4, 464.47, 486.53, 508.6, 530.67, 552.73, 574.8, 596.87, 618.93]
#      id  target_original  loan  mortdue     value   reason     job   yoj  \
# 0  0001                1  1100  25860.0   39025.0  HomeImp   Other  10.5
# 1  0002                1  1300  70053.0   68400.0  HomeImp   Other   7.0
# 2  0003                1  1500  13500.0   16700.0  HomeImp   Other   4.0
# 3  0004                1  1500      NaN       NaN      NaN     NaN   NaN
# 4  0005                0  1700  97800.0  112000.0  HomeImp  Office   3.0
#
#    derog  delinq       clage  ninq  clno  debtinc   decision  target  \
# 0    0.0     0.0   94.366667   1.0   9.0      NaN   aprobado       1
# 1    0.0     2.0  121.833333   0.0  14.0      NaN   aprobado       1
# 2    0.0     0.0  149.466667   1.0  10.0      NaN   aprobado       1
# 3    NaN     NaN         NaN   NaN   NaN      NaN   aprobado       1
# 4    0.0     0.0   93.333333   0.0  14.0      NaN  rechazado      -3
#
#    scorecardpoints_acep  parcel  target_inf  target_def
# 0                 470.0       8         NaN         1.0
# 1                 493.0       9         NaN         1.0
# 2                 496.0       9         NaN         1.0
# 3                 440.0       6         NaN         1.0
# 4                 522.0      10         0.0         0.0

# %% [markdown]
# <span style='color:blue'>Ahora que ya tenemos a los denegados con un target inferido desarrollamos otra scorecard con una nueva partición 70-30 (usando todos, aceptados + denegados)

# %%
X_def, y_def = df3[X.columns], df3.target_def

# %%
modelo_todos = pyk.autoscorecard(excluded_vars=['id', 'target_original', 'decision', 'debtinc'], save_whole_tables=True).fit(X_def, y_def)
# Out:
# Particionado 70-30 estratificado en el target terminado.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Variables no agrupadas: ['reason', 'job']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Cuidado, has puesto un valor numero máximo de iteraciones (12) superior al número de variables candidatas (9)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Step 01 | Time - 0:00:00.490329 | p-value = 7.92e-91 | Gini train = 34.75% | Gini test = 32.90% ---> Feature selected: delinq
# Step 02 | Time - 0:00:00.632102 | p-value = 7.45e-48 | Gini train = 52.12% | Gini test = 51.61% ---> Feature selected: clage
# Step 03 | Time - 0:00:00.686805 | p-value = 1.96e-36 | Gini train = 58.30% | Gini test = 59.75% ---> Feature selected: value
# Step 04 | Time - 0:00:00.693111 | p-value = 9.91e-28 | Gini train = 60.76% | Gini test = 64.64% ---> Feature selected: derog
# Step 05 | Time - 0:00:00.704654 | p-value = 2.62e-22 | Gini train = 63.60% | Gini test = 65.42% ---> Feature selected: loan
# Step 06 | Time - 0:00:00.693498 | p-value = 3.23e-15 | Gini train = 64.84% | Gini test = 66.83% ---> Feature selected: ninq
# Step 07 | Time - 0:00:00.650359 | p-value = 6.69e-12 | Gini train = 66.78% | Gini test = 68.22% ---> Feature selected: yoj
# Step 08 | Time - 0:00:00.592246 | p-value = 1.20e-09 | Gini train = 67.97% | Gini test = 69.48% ---> Feature selected: clno
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Ya ninguna variable tiene un p-valor < 0.01, detenemos el proceso.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['delinq', 'clage', 'value', 'derog', 'loan', 'ninq', 'yoj', 'clno']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 53.46% de KS y un 67.97% de Gini en la muestra de desarrollo
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 56.19% de KS y un 69.48% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
modelo_def = modelo_todos

# %% [markdown]
# <span style='color:blue'>Evaluamos el modelo también solo sobre los aceptados (en el 70-30 del último modelo)

# %%
data_train = modelo_def.X_train.copy()
data_train['target'] = modelo_def.y_train
data_train_oa = data_train[data_train.decision == 'aprobado'].reset_index(drop=True)
data_train_final_oa, ks_train_oa, gini_train_oa = modelo_def.transform(data_train_oa, target_name='target', metrics=['ks', 'gini'])
# Out:
# El modelo tiene un 50.11% de KS y un 64.69% de Gini en esta muestra

# %%
data_test = modelo_def.X_test.copy()
data_test['target'] = modelo_def.y_test
data_test_oa = data_test[data_test.decision == 'aprobado'].reset_index(drop=True)
data_test_final_oa, ks_test_oa, gini_test_oa = modelo_def.transform(data_test_oa, target_name='target', metrics=['ks', 'gini'])
# Out:
# El modelo tiene un 56.75% de KS y un 69.13% de Gini en esta muestra

# %% [markdown]
# <span style='color:blue'>Pintamos la scorecard final

# %%
pyk.pretty_scorecard(modelo_def)
# Out:
# <style type="text/css">
# #T_4a46e_row0_col0, #T_4a46e_row0_col1, #T_4a46e_row0_col2, #T_4a46e_row0_col3, #T_4a46e_row0_col4, #T_4a46e_row0_col5, #T_4a46e_row0_col6, #T_4a46e_row0_col7, #T_4a46e_row0_col8, #T_4a46e_row0_col9, #T_4a46e_row0_col10, #T_4a46e_row1_col0, #T_4a46e_row1_col1, #T_4a46e_row1_col2, #T_4a46e_row1_col3, #T_4a46e_row1_col4, #T_4a46e_row1_col5, #T_4a46e_row1_col6, #T_4a46e_row1_col7, #T_4a46e_row1_col8, #T_4a46e_row1_col9, #T_4a46e_row1_col10, #T_4a46e_row2_col0, #T_4a46e_row2_col1, #T_4a46e_row2_col2, #T_4a46e_row2_col3, #T_4a46e_row2_col4, #T_4a46e_row2_col5, #T_4a46e_row2_col6, #T_4a46e_row2_col7, #T_4a46e_row2_col8, #T_4a46e_row2_col9, #T_4a46e_row2_col10, #T_4a46e_row3_col0, #T_4a46e_row3_col1, #T_4a46e_row3_col2, #T_4a46e_row3_col3, #T_4a46e_row3_col4, #T_4a46e_row3_col5, #T_4a46e_row3_col6, #T_4a46e_row3_col7, #T_4a46e_row3_col8, #T_4a46e_row3_col9, #T_4a46e_row3_col10, #T_4a46e_row10_col0, #T_4a46e_row10_col1, #T_4a46e_row10_col2, #T_4a46e_row10_col3, #T_4a46e_row10_col4, #T_4a46e_row10_col5, #T_4a46e_row10_col6, #T_4a46e_row10_col7, #T_4a46e_row10_col8, #T_4a46e_row10_col9, #T_4a46e_row10_col10, #T_4a46e_row11_col0, #T_4a46e_row11_col1, #T_4a46e_row11_col2, #T_4a46e_row11_col3, #T_4a46e_row11_col4, #T_4a46e_row11_col5, #T_4a46e_row11_col6, #T_4a46e_row11_col7, #T_4a46e_row11_col8, #T_4a46e_row11_col9, #T_4a46e_row11_col10, #T_4a46e_row12_col0, #T_4a46e_row12_col1, #T_4a46e_row12_col2, #T_4a46e_row12_col3, #T_4a46e_row12_col4, #T_4a46e_row12_col5, #T_4a46e_row12_col6, #T_4a46e_row12_col7, #T_4a46e_row12_col8, #T_4a46e_row12_col9, #T_4a46e_row12_col10, #T_4a46e_row13_col0, #T_4a46e_row13_col1, #T_4a46e_row13_col2, #T_4a46e_row13_col3, #T_4a46e_row13_col4, #T_4a46e_row13_col5, #T_4a46e_row13_col6, #T_4a46e_row13_col7, #T_4a46e_row13_col8, #T_4a46e_row13_col9, #T_4a46e_row13_col10, #T_4a46e_row14_col0, #T_4a46e_row14_col1, #T_4a46e_row14_col2, #T_4a46e_row14_col3, #T_4a46e_row14_col4, #T_4a46e_row14_col5, #T_4a46e_row14_col6, #T_4a46e_row14_col7, #T_4a46e_row14_col8, #T_4a46e_row14_col9, #T_4a46e_row14_col10, #T_4a46e_row15_col0, #T_4a46e_row15_col1, #T_4a46e_row15_col2, #T_4a46e_row15_col3, #T_4a46e_row15_col4, #T_4a46e_row15_col5, #T_4a46e_row15_col6, #T_4a46e_row15_col7, #T_4a46e_row15_col8, #T_4a46e_row15_col9, #T_4a46e_row15_col10, #T_4a46e_row20_col0, #T_4a46e_row20_col1, #T_4a46e_row20_col2, #T_4a46e_row20_col3, #T_4a46e_row20_col4, #T_4a46e_row20_col5, #T_4a46e_row20_col6, #T_4a46e_row20_col7, #T_4a46e_row20_col8, #T_4a46e_row20_col9, #T_4a46e_row20_col10, #T_4a46e_row21_col0, #T_4a46e_row21_col1, #T_4a46e_row21_col2, #T_4a46e_row21_col3, #T_4a46e_row21_col4, #T_4a46e_row21_col5, #T_4a46e_row21_col6, #T_4a46e_row21_col7, #T_4a46e_row21_col8, #T_4a46e_row21_col9, #T_4a46e_row21_col10, #T_4a46e_row22_col0, #T_4a46e_row22_col1, #T_4a46e_row22_col2, #T_4a46e_row22_col3, #T_4a46e_row22_col4, #T_4a46e_row22_col5, #T_4a46e_row22_col6, #T_4a46e_row22_col7, #T_4a46e_row22_col8, #T_4a46e_row22_col9, #T_4a46e_row22_col10, #T_4a46e_row23_col0, #T_4a46e_row23_col1, #T_4a46e_row23_col2, #T_4a46e_row23_col3, #T_4a46e_row23_col4, #T_4a46e_row23_col5, #T_4a46e_row23_col6, #T_4a46e_row23_col7, #T_4a46e_row23_col8, #T_4a46e_row23_col9, #T_4a46e_row23_col10, #T_4a46e_row24_col0, #T_4a46e_row24_col1, #T_4a46e_row24_col2, #T_4a46e_row24_col3, #T_4a46e_row24_col4, #T_4a46e_row24_col5, #T_4a46e_row24_col6, #T_4a46e_row24_col7, #T_4a46e_row24_col8, #T_4a46e_row24_col9, #T_4a46e_row24_col10, #T_4a46e_row31_col0, #T_4a46e_row31_col1, #T_4a46e_row31_col2, #T_4a46e_row31_col3, #T_4a46e_row31_col4, #T_4a46e_row31_col5, #T_4a46e_row31_col6, #T_4a46e_row31_col7, #T_4a46e_row31_col8, #T_4a46e_row31_col9, #T_4a46e_row31_col10, #T_4a46e_row32_col0, #T_4a46e_row32_col1, #T_4a46e_row32_col2, #T_4a46e_row32_col3, #T_4a46e_row32_col4, #T_4a46e_row32_col5, #T_4a46e_row32_col6, #T_4a46e_row32_col7, #T_4a46e_row32_col8, #T_4a46e_row32_col9, #T_4a46e_row32_col10, #T_4a46e_row33_col0, #T_4a46e_row33_col1, #T_4a46e_row33_col2, #T_4a46e_row33_col3, #T_4a46e_row33_c ...
#   background-color: #CCECFF;
# }
# #T_4a46e_row4_col0, #T_4a46e_row4_col1, #T_4a46e_row4_col2, #T_4a46e_row4_col3, #T_4a46e_row4_col4, #T_4a46e_row4_col5, #T_4a46e_row4_col6, #T_4a46e_row4_col7, #T_4a46e_row4_col8, #T_4a46e_row4_col9, #T_4a46e_row4_col10, #T_4a46e_row5_col0, #T_4a46e_row5_col1, #T_4a46e_row5_col2, #T_4a46e_row5_col3, #T_4a46e_row5_col4, #T_4a46e_row5_col5, #T_4a46e_row5_col6, #T_4a46e_row5_col7, #T_4a46e_row5_col8, #T_4a46e_row5_col9, #T_4a46e_row5_col10, #T_4a46e_row6_col0, #T_4a46e_row6_col1, #T_4a46e_row6_col2, #T_4a46e_row6_col3, #T_4a46e_row6_col4, #T_4a46e_row6_col5, #T_4a46e_row6_col6, #T_4a46e_row6_col7, #T_4a46e_row6_col8, #T_4a46e_row6_col9, #T_4a46e_row6_col10, #T_4a46e_row7_col0, #T_4a46e_row7_col1, #T_4a46e_row7_col2, #T_4a46e_row7_col3, #T_4a46e_row7_col4, #T_4a46e_row7_col5, #T_4a46e_row7_col6, #T_4a46e_row7_col7, #T_4a46e_row7_col8, #T_4a46e_row7_col9, #T_4a46e_row7_col10, #T_4a46e_row8_col0, #T_4a46e_row8_col1, #T_4a46e_row8_col2, #T_4a46e_row8_col3, #T_4a46e_row8_col4, #T_4a46e_row8_col5, #T_4a46e_row8_col6, #T_4a46e_row8_col7, #T_4a46e_row8_col8, #T_4a46e_row8_col9, #T_4a46e_row8_col10, #T_4a46e_row9_col0, #T_4a46e_row9_col1, #T_4a46e_row9_col2, #T_4a46e_row9_col3, #T_4a46e_row9_col4, #T_4a46e_row9_col5, #T_4a46e_row9_col6, #T_4a46e_row9_col7, #T_4a46e_row9_col8, #T_4a46e_row9_col9, #T_4a46e_row9_col10, #T_4a46e_row16_col0, #T_4a46e_row16_col1, #T_4a46e_row16_col2, #T_4a46e_row16_col3, #T_4a46e_row16_col4, #T_4a46e_row16_col5, #T_4a46e_row16_col6, #T_4a46e_row16_col7, #T_4a46e_row16_col8, #T_4a46e_row16_col9, #T_4a46e_row16_col10, #T_4a46e_row17_col0, #T_4a46e_row17_col1, #T_4a46e_row17_col2, #T_4a46e_row17_col3, #T_4a46e_row17_col4, #T_4a46e_row17_col5, #T_4a46e_row17_col6, #T_4a46e_row17_col7, #T_4a46e_row17_col8, #T_4a46e_row17_col9, #T_4a46e_row17_col10, #T_4a46e_row18_col0, #T_4a46e_row18_col1, #T_4a46e_row18_col2, #T_4a46e_row18_col3, #T_4a46e_row18_col4, #T_4a46e_row18_col5, #T_4a46e_row18_col6, #T_4a46e_row18_col7, #T_4a46e_row18_col8, #T_4a46e_row18_col9, #T_4a46e_row18_col10, #T_4a46e_row19_col0, #T_4a46e_row19_col1, #T_4a46e_row19_col2, #T_4a46e_row19_col3, #T_4a46e_row19_col4, #T_4a46e_row19_col5, #T_4a46e_row19_col6, #T_4a46e_row19_col7, #T_4a46e_row19_col8, #T_4a46e_row19_col9, #T_4a46e_row19_col10, #T_4a46e_row25_col0, #T_4a46e_row25_col1, #T_4a46e_row25_col2, #T_4a46e_row25_col3, #T_4a46e_row25_col4, #T_4a46e_row25_col5, #T_4a46e_row25_col6, #T_4a46e_row25_col7, #T_4a46e_row25_col8, #T_4a46e_row25_col9, #T_4a46e_row25_col10, #T_4a46e_row26_col0, #T_4a46e_row26_col1, #T_4a46e_row26_col2, #T_4a46e_row26_col3, #T_4a46e_row26_col4, #T_4a46e_row26_col5, #T_4a46e_row26_col6, #T_4a46e_row26_col7, #T_4a46e_row26_col8, #T_4a46e_row26_col9, #T_4a46e_row26_col10, #T_4a46e_row27_col0, #T_4a46e_row27_col1, #T_4a46e_row27_col2, #T_4a46e_row27_col3, #T_4a46e_row27_col4, #T_4a46e_row27_col5, #T_4a46e_row27_col6, #T_4a46e_row27_col7, #T_4a46e_row27_col8, #T_4a46e_row27_col9, #T_4a46e_row27_col10, #T_4a46e_row28_col0, #T_4a46e_row28_col1, #T_4a46e_row28_col2, #T_4a46e_row28_col3, #T_4a46e_row28_col4, #T_4a46e_row28_col5, #T_4a46e_row28_col6, #T_4a46e_row28_col7
