# %% [markdown]
# En este notebook utilizamos un nuevo dataset donde vemos como hacer `agrupaciones manuales` y mostramos como se maneja Memento con los `missings`

# %% [markdown]
# <span style='color:blue'>Importamos los módulos

# %%
import numpy as np, pandas as pd, pyken as pyk

# %% [markdown]
# <span style='color:blue'>Cargamos el dataset

# %%
data = pd.read_csv('stroke_data.csv')
X, y = data.drop('stroke', axis=1), data['stroke']
print('El dataset tiene {} filas y {} columnas'.format(X.shape[0], X.shape[1]))
# Out:
# El dataset tiene 5110 filas y 11 columnas

# %% [markdown]
# <span style='color:blue'>No todas las variables son numéricas

# %%
X.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %% [markdown]
# <span style='color:blue'>La variable `bmi` es la única que tiene missings

# %%
X.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# dtype: int64

# %% [markdown]
# <span style='color:blue'>Vamos a meter missings también en la variable categórica `work_type` quitando la categoria 'Self-employed'

# %%
X['work_type'] = X['work_type'].replace('Self-employed', np.nan)
X.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type            819
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# dtype: int64

# %% [markdown]
# <span style='color:blue'>Probamos a sacar la scorecard automática. Excluimos la variable `id` por motivos evidentes

# %%
modelo1 = pyk.autoscorecard(excluded_vars=['id']).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Cuidado, has puesto un valor numero máximo de iteraciones (12) superior al número de variables candidatas (9)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Step 01 | Time - 0:00:00.588744 | p-value = 1.89e-36 | Gini train = 64.73% | Gini test = 66.78% ---> Feature selected: age
# Step 02 | Time - 0:00:00.594736 | p-value = 5.95e-11 | Gini train = 70.88% | Gini test = 67.94% ---> Feature selected: bmi
# Step 03 | Time - 0:00:00.564792 | p-value = 1.58e-05 | Gini train = 72.59% | Gini test = 68.10% ---> Feature selected: avg_glucose_level
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Ya ninguna variable tiene un p-valor < 0.01, detenemos el proceso.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['age', 'bmi', 'avg_glucose_level']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 59.52% de KS y un 72.59% de Gini en la muestra de desarrollo
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 57.68% de KS y un 68.10% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>Pintamos la scorecard con colorines

# %%
pyk.pretty_scorecard(modelo1)
# Out:
# <style type="text/css">
# #T_a43b8_row0_col0, #T_a43b8_row0_col1, #T_a43b8_row0_col2, #T_a43b8_row0_col3, #T_a43b8_row0_col4, #T_a43b8_row0_col5, #T_a43b8_row0_col6, #T_a43b8_row0_col7, #T_a43b8_row0_col8, #T_a43b8_row0_col9, #T_a43b8_row0_col10, #T_a43b8_row1_col0, #T_a43b8_row1_col1, #T_a43b8_row1_col2, #T_a43b8_row1_col3, #T_a43b8_row1_col4, #T_a43b8_row1_col5, #T_a43b8_row1_col6, #T_a43b8_row1_col7, #T_a43b8_row1_col8, #T_a43b8_row1_col9, #T_a43b8_row1_col10, #T_a43b8_row2_col0, #T_a43b8_row2_col1, #T_a43b8_row2_col2, #T_a43b8_row2_col3, #T_a43b8_row2_col4, #T_a43b8_row2_col5, #T_a43b8_row2_col6, #T_a43b8_row2_col7, #T_a43b8_row2_col8, #T_a43b8_row2_col9, #T_a43b8_row2_col10, #T_a43b8_row3_col0, #T_a43b8_row3_col1, #T_a43b8_row3_col2, #T_a43b8_row3_col3, #T_a43b8_row3_col4, #T_a43b8_row3_col5, #T_a43b8_row3_col6, #T_a43b8_row3_col7, #T_a43b8_row3_col8, #T_a43b8_row3_col9, #T_a43b8_row3_col10, #T_a43b8_row4_col0, #T_a43b8_row4_col1, #T_a43b8_row4_col2, #T_a43b8_row4_col3, #T_a43b8_row4_col4, #T_a43b8_row4_col5, #T_a43b8_row4_col6, #T_a43b8_row4_col7, #T_a43b8_row4_col8, #T_a43b8_row4_col9, #T_a43b8_row4_col10, #T_a43b8_row11_col0, #T_a43b8_row11_col1, #T_a43b8_row11_col2, #T_a43b8_row11_col3, #T_a43b8_row11_col4, #T_a43b8_row11_col5, #T_a43b8_row11_col6, #T_a43b8_row11_col7, #T_a43b8_row11_col8, #T_a43b8_row11_col9, #T_a43b8_row11_col10, #T_a43b8_row12_col0, #T_a43b8_row12_col1, #T_a43b8_row12_col2, #T_a43b8_row12_col3, #T_a43b8_row12_col4, #T_a43b8_row12_col5, #T_a43b8_row12_col6, #T_a43b8_row12_col7, #T_a43b8_row12_col8, #T_a43b8_row12_col9, #T_a43b8_row12_col10, #T_a43b8_row13_col0, #T_a43b8_row13_col1, #T_a43b8_row13_col2, #T_a43b8_row13_col3, #T_a43b8_row13_col4, #T_a43b8_row13_col5, #T_a43b8_row13_col6, #T_a43b8_row13_col7, #T_a43b8_row13_col8, #T_a43b8_row13_col9, #T_a43b8_row13_col10, #T_a43b8_row14_col0, #T_a43b8_row14_col1, #T_a43b8_row14_col2, #T_a43b8_row14_col3, #T_a43b8_row14_col4, #T_a43b8_row14_col5, #T_a43b8_row14_col6, #T_a43b8_row14_col7, #T_a43b8_row14_col8, #T_a43b8_row14_col9, #T_a43b8_row14_col10, #T_a43b8_row15_col0, #T_a43b8_row15_col1, #T_a43b8_row15_col2, #T_a43b8_row15_col3, #T_a43b8_row15_col4, #T_a43b8_row15_col5, #T_a43b8_row15_col6, #T_a43b8_row15_col7, #T_a43b8_row15_col8, #T_a43b8_row15_col9, #T_a43b8_row15_col10 {
#   background-color: #CCECFF;
# }
# #T_a43b8_row5_col0, #T_a43b8_row5_col1, #T_a43b8_row5_col2, #T_a43b8_row5_col3, #T_a43b8_row5_col4, #T_a43b8_row5_col5, #T_a43b8_row5_col6, #T_a43b8_row5_col7, #T_a43b8_row5_col8, #T_a43b8_row5_col9, #T_a43b8_row5_col10, #T_a43b8_row6_col0, #T_a43b8_row6_col1, #T_a43b8_row6_col2, #T_a43b8_row6_col3, #T_a43b8_row6_col4, #T_a43b8_row6_col5, #T_a43b8_row6_col6, #T_a43b8_row6_col7, #T_a43b8_row6_col8, #T_a43b8_row6_col9, #T_a43b8_row6_col10, #T_a43b8_row7_col0, #T_a43b8_row7_col1, #T_a43b8_row7_col2, #T_a43b8_row7_col3, #T_a43b8_row7_col4, #T_a43b8_row7_col5, #T_a43b8_row7_col6, #T_a43b8_row7_col7, #T_a43b8_row7_col8, #T_a43b8_row7_col9, #T_a43b8_row7_col10, #T_a43b8_row8_col0, #T_a43b8_row8_col1, #T_a43b8_row8_col2, #T_a43b8_row8_col3, #T_a43b8_row8_col4, #T_a43b8_row8_col5, #T_a43b8_row8_col6, #T_a43b8_row8_col7, #T_a43b8_row8_col8, #T_a43b8_row8_col9, #T_a43b8_row8_col10, #T_a43b8_row9_col0, #T_a43b8_row9_col1, #T_a43b8_row9_col2, #T_a43b8_row9_col3, #T_a43b8_row9_col4, #T_a43b8_row9_col5, #T_a43b8_row9_col6, #T_a43b8_row9_col7, #T_a43b8_row9_col8, #T_a43b8_row9_col9, #T_a43b8_row9_col10, #T_a43b8_row10_col0, #T_a43b8_row10_col1, #T_a43b8_row10_col2, #T_a43b8_row10_col3, #T_a43b8_row10_col4, #T_a43b8_row10_col5, #T_a43b8_row10_col6, #T_a43b8_row10_col7, #T_a43b8_row10_col8, #T_a43b8_row10_col9, #T_a43b8_row10_col10 {
#   background-color: #FFFFFF;
# }
# </style>
# <table id="T_a43b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a43b8_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_a43b8_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_a43b8_level0_col2" class="col_heading level0 col2" >Count</th>
#       <th id="T_a43b8_level0_col3" class="col_heading level0 col3" >Percent</th>
#       <th id="T_a43b8_level0_col4" class="col_heading level0 col4" >Goods</th>
#       <th id="T_a43b8_level0_col5" class="col_heading level0 col5" >Bads</th>
#       <th id="T_a43b8_level0_col6" class="col_heading level0 col6" >Bad rate</th>
#       <th id="T_a43b8_level0_col7" class="col_heading level0 col7" >WoE</th>
#       <th id="T_a43b8_level0_col8" class="col_heading level0 col8" >IV</th>
#       <th id="T_a43b8_level0_col9" class="col_heading level0 col9" >Raw score</th>
#       <th id="T_a43b8_level0_col10" class="col_heading level0 col10" >Aligned score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a43b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a43b8_row0_col0" class="data row0 col0" >age</td>
#       <td id="T_a43b8_row0_col1" class="data row0 col1" >(-inf, 48.50)</td>
#       <td id="T_a43b8_row0_col2" class="data row0 col2" >1996</td>
#       <td id="T_a43b8_row0_col3" class="data row0 col3" >0.558010</td>
#       <td id="T_a43b8_row0_col4" class="data row0 col4" >1984</td>
#       <td id="T_a43b8_row0_col5" class="data row0 col5" >12</td>
#       <td id="T_a43b8_row0_col6" class="data row0 col6" >0.006012</td>
#       <td id="T_a43b8_row0_col7" class="data row0 col7" >2.134606</td>
#       <td id="T_a43b8_row0_col8" class="data row0 col8" >1.097293</td>
#       <td id="T_a43b8_row0_col9" class="data row0 col9" >-1.958686</td>
#       <td id="T_a43b8_row0_col10" class="data row0 col10" >252</td>
#     </tr>
#     <tr>
#       <th id="T_a43b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a43b8_row1_col0" class="data row1 col0" >age</td>
#       <td id="T_a43b8_row1_col1" class="data row1 col1" >[48.50, 56.50)</td>
#       <td id="T_a43b8_row1_col2" class="data row1 col2" >454</td>
#       <td id="T_a43b8_row1_col3" class="data row1 col3" >0.126922</td>
#       <td id="T_a43b8_row1_col4" class="data row1 col4" >434</td>
#       <td id="T_a43b8_row1_col5" class="data row1 col5" >20</td>
#       <td id="T_a43b8_row1_col6" class="data row1 col6" >0.044053</td>
#       <td id="T_a43b8_row1_col7" class="data row1 col7" >0.103955</td>
#       <td id="T_a43b8_row1_col8" class="data row1 col8" >0.001309</td>
#       <td id="T_a43b8_row1_col9" class="data row1 col9" >-0.095388</td>
#       <td id="T_a43b8_row1_col10" class="data row1 col10" >198</td>
#     </tr>
#     <tr>
#       <th id="T_a43b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a43b8_row2_col0" class="data row2 col0" >age</td>
#       <td id="T_a43b8_row2_col1" class="data row2 col1" >[56.50, 67.50)</td>
#       <td id="T_a43b8_row2_col2" class="data row2 col2" >535</td>
#       <td id="T_a43b8_row2_col3" class="data row2 col3" >0.149567</td>
#       <td id="T_a43b8_row2_col4" class="data row2 col4" >496</td>
#       <td id="T_a43b8_row2_col5" class="data row2 col5" >39</td>
#       <td id="T_a43b8_row2_col6" class="data row2 col6" >0.072897</td>
#       <td id="T_a43b8_row2_col7" class="data row2 col7" >-0.430343</td>
#       <td id="T_a43b8_row2_col8" class="data row2 col8" >0.033732</td>
#       <td id="T_a43b8_row2_col9" class="data row2 col9" >0.394877</td>
#       <td id="T_a43b8_row2_col10" class="data row2 col10" >184</td>
#     </tr>
#     <tr>
#       <th id="T_a43b8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a43b8_row3_col0" class="data row3 col0" >age</td>
#       <td id="T_a43b8_row3_col1" class="data row3 col1" >[67.50, 75.50)</td>
#       <td id="T_a43b8_row3_col2" class="data row3 col2" >278</td>
#       <td id="T_a43b8_row3_col3" class="data row3 col3" >0.077719</td>
#       <td id="T_a43b8_row3_col4" class="data row3 col4" >238</td>
#       <td id="T_a43b8_row3_col5" class="data row3 col5" >40</td>
#       <td id="T_a43b8_row3_col6" class="data row3 col6" >0.143885</td>
#       <td id="T_a43b8_row3_col7" class="data row3 col7" >-1.189966</td>
#       <td id="T_a43b8_row3_col8" class="data row3 col8" >0.190331</td>
#       <td id="T_a

# %% [markdown]
# <span style='color:red'>¿Y si no quiero usar las agrupaciones del autogrouping?... ¿Y si quiero modificarlas o directamente usar las que a mí me de la gana?

# %% [markdown]
# <span style='color:blue'>Lo recomendado para reagruparar variables manualmente es poner en `candidate_var`el nombre de la variable que se quiere reagrupar y en `modelo_newgroups` el objeto modelo

# %%
candidate_var, modelo_newgroups = 'age', modelo1
objeto = modelo_newgroups.objetos[candidate_var]

# %% [markdown]
# <span style='color:blue'>Así vemos primero, a modo de referencia, que tabla teníamos con la agrupación automática del autogrouping

# %%
if objeto.dtype != 'O': L = [round(i, 4) for  i in list(objeto.breakpoints)]
else: L = objeto.breakpoints
print('Resultado del autogrouping de {}: {} \n'.format(candidate_var, L))
display(objeto.table)
# Out:
# Resultado del autogrouping de age: [48.5, 56.5, 67.5, 75.5]
#                  Group  Count   Percent  Goods  Bads  Bad rate       WoE  \
# 0        (-inf, 48.50)   1996  0.558010   1984    12  0.006012  2.134606
# 1       [48.50, 56.50)    454  0.126922    434    20  0.044053  0.103955
# 2       [56.50, 67.50)    535  0.149567    496    39  0.072897 -0.430343
# 3       [67.50, 75.50)    278  0.077719    238    40  0.143885 -1.189966
# 4         [75.50, inf)    314  0.087783    251    63  0.200637 -1.591039
# Totals                   3577  1.000000   3403   174  0.048644
#
#               IV
# 0       1.097293
# 1       0.001309
# 2       0.033732
# 3       0.190331
# 4       0.458713
# Totals  1.781379

# %% [markdown]
# <span style='color:blue'>En la siguiente celda podemos toquetear y modifcar los puntos de ruptura entre los grupos, viendo interactivamente como se actualiza la tabla

# %%
bp = [30, 60]

vector = pyk.data_convert(pyk.string_categories2(bp)).fit(modelo_newgroups.X_train[candidate_var]).x_final
breakpoints_num = pyk.breakpoints_to_num(bp)
groups_names = pyk.compute_group_names(objeto.dtype, bp)
                                      
pyk.compute_table(vector, modelo_newgroups.y_train, breakpoints_num, groups_names)
# Out:
#                  Group  Count   Percent  Goods  Bads  Bad rate       WoE  \
# 0        (-inf, 30.00)   1077  0.301090   1075     2  0.001857  3.313571
# 1       [30.00, 60.00)   1538  0.429969   1494    44  0.028609  0.551665
# 2         [60.00, inf)    962  0.268940    834   128  0.133056 -1.099154
# Totals                   3577  1.000000   3403   174  0.048644
#
#               IV
# 0       1.008663
# 1       0.102693
# 2       0.539195
# Totals  1.650550

# %% [markdown]
# <span style='color:blue'>Para usar esta nueva agrupación de la variable `age` lanzamos de nuevo una scorecard con la agrupación en `user_breakpoints`

# %%
modelo2 = pyk.autoscorecard(excluded_vars=['id'], user_breakpoints={'age': [30, 60]}).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Cuidado, has puesto un valor numero máximo de iteraciones (12) superior al número de variables candidatas (9)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Step 01 | Time - 0:00:00.502078 | p-value = 8.28e-27 | Gini train = 56.54% | Gini test = 54.72% ---> Feature selected: age
# Step 02 | Time - 0:00:00.510524 | p-value = 1.99e-10 | Gini train = 64.46% | Gini test = 58.66% ---> Feature selected: bmi
# Step 03 | Time - 0:00:00.607537 | p-value = 1.01e-06 | Gini train = 67.69% | Gini test = 60.01% ---> Feature selected: avg_glucose_level
# Step 04 | Time - 0:00:00.537691 | p-value = 7.25e-03 | Gini train = 68.77% | Gini test = 60.41% ---> Feature selected: hypertension
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Ya ninguna variable tiene un p-valor < 0.01, detenemos el proceso.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['age', 'bmi', 'avg_glucose_level', 'hypertension']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 53.96% de KS y un 68.77% de Gini en la muestra de desarrollo
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 47.72% de KS y un 60.41% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:red'>Perooooo... ¿Por qué ahora entra `hypertension`!?!?

# %% [markdown]
# <span style='color:blue'>Si te fijas, con la nueva agrupación, `age` es aparentemente menos discriminante: ahora en el primer paso el modelo tiene un 56.54% de gini en train cuando antes, con la agrupación automática, en el primer paso el modelo tenía un 64.73%. Por este motivo ahora al final el método de selección de variables acaba escogiendo también a `hypertension`

# %% [markdown]
# <span style='color:blue'>Si se quisiera evitar esto, se puede introducir las variables exactas que queremos formen parte de la scorecard en el parámetro `features`

# %%
modelo3 = pyk.autoscorecard(features=['age', 'bmi', 'avg_glucose_level'], user_breakpoints={'age': [30, 60]}).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Step 01 | Time - 0:00:00.000000 | p-value = 8.28e-27 | Gini train = 56.54% | Gini test = 54.72% ---> Feature selected: age
# Step 02 | Time - 0:00:00.000000 | p-value = 1.99e-10 | Gini train = 64.46% | Gini test = 58.66% ---> Feature selected: bmi
# Step 03 | Time - 0:00:00.000000 | p-value = 1.01e-06 | Gini train = 67.69% | Gini test = 60.01% ---> Feature selected: avg_glucose_level
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['age', 'bmi', 'avg_glucose_level']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 52.66% de KS y un 67.69% de Gini en la muestra de desarrollo
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 47.89% de KS y un 60.01% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>Vemos como quedaría la scorecard

# %%
pyk.pretty_scorecard(modelo3, color1='green')
# Out:
# <style type="text/css">
# #T_5c99b_row0_col0, #T_5c99b_row0_col1, #T_5c99b_row0_col2, #T_5c99b_row0_col3, #T_5c99b_row0_col4, #T_5c99b_row0_col5, #T_5c99b_row0_col6, #T_5c99b_row0_col7, #T_5c99b_row0_col8, #T_5c99b_row0_col9, #T_5c99b_row0_col10, #T_5c99b_row1_col0, #T_5c99b_row1_col1, #T_5c99b_row1_col2, #T_5c99b_row1_col3, #T_5c99b_row1_col4, #T_5c99b_row1_col5, #T_5c99b_row1_col6, #T_5c99b_row1_col7, #T_5c99b_row1_col8, #T_5c99b_row1_col9, #T_5c99b_row1_col10, #T_5c99b_row2_col0, #T_5c99b_row2_col1, #T_5c99b_row2_col2, #T_5c99b_row2_col3, #T_5c99b_row2_col4, #T_5c99b_row2_col5, #T_5c99b_row2_col6, #T_5c99b_row2_col7, #T_5c99b_row2_col8, #T_5c99b_row2_col9, #T_5c99b_row2_col10, #T_5c99b_row9_col0, #T_5c99b_row9_col1, #T_5c99b_row9_col2, #T_5c99b_row9_col3, #T_5c99b_row9_col4, #T_5c99b_row9_col5, #T_5c99b_row9_col6, #T_5c99b_row9_col7, #T_5c99b_row9_col8, #T_5c99b_row9_col9, #T_5c99b_row9_col10, #T_5c99b_row10_col0, #T_5c99b_row10_col1, #T_5c99b_row10_col2, #T_5c99b_row10_col3, #T_5c99b_row10_col4, #T_5c99b_row10_col5, #T_5c99b_row10_col6, #T_5c99b_row10_col7, #T_5c99b_row10_col8, #T_5c99b_row10_col9, #T_5c99b_row10_col10, #T_5c99b_row11_col0, #T_5c99b_row11_col1, #T_5c99b_row11_col2, #T_5c99b_row11_col3, #T_5c99b_row11_col4, #T_5c99b_row11_col5, #T_5c99b_row11_col6, #T_5c99b_row11_col7, #T_5c99b_row11_col8, #T_5c99b_row11_col9, #T_5c99b_row11_col10, #T_5c99b_row12_col0, #T_5c99b_row12_col1, #T_5c99b_row12_col2, #T_5c99b_row12_col3, #T_5c99b_row12_col4, #T_5c99b_row12_col5, #T_5c99b_row12_col6, #T_5c99b_row12_col7, #T_5c99b_row12_col8, #T_5c99b_row12_col9, #T_5c99b_row12_col10, #T_5c99b_row13_col0, #T_5c99b_row13_col1, #T_5c99b_row13_col2, #T_5c99b_row13_col3, #T_5c99b_row13_col4, #T_5c99b_row13_col5, #T_5c99b_row13_col6, #T_5c99b_row13_col7, #T_5c99b_row13_col8, #T_5c99b_row13_col9, #T_5c99b_row13_col10 {
#   background-color: #CCFFCC;
# }
# #T_5c99b_row3_col0, #T_5c99b_row3_col1, #T_5c99b_row3_col2, #T_5c99b_row3_col3, #T_5c99b_row3_col4, #T_5c99b_row3_col5, #T_5c99b_row3_col6, #T_5c99b_row3_col7, #T_5c99b_row3_col8, #T_5c99b_row3_col9, #T_5c99b_row3_col10, #T_5c99b_row4_col0, #T_5c99b_row4_col1, #T_5c99b_row4_col2, #T_5c99b_row4_col3, #T_5c99b_row4_col4, #T_5c99b_row4_col5, #T_5c99b_row4_col6, #T_5c99b_row4_col7, #T_5c99b_row4_col8, #T_5c99b_row4_col9, #T_5c99b_row4_col10, #T_5c99b_row5_col0, #T_5c99b_row5_col1, #T_5c99b_row5_col2, #T_5c99b_row5_col3, #T_5c99b_row5_col4, #T_5c99b_row5_col5, #T_5c99b_row5_col6, #T_5c99b_row5_col7, #T_5c99b_row5_col8, #T_5c99b_row5_col9, #T_5c99b_row5_col10, #T_5c99b_row6_col0, #T_5c99b_row6_col1, #T_5c99b_row6_col2, #T_5c99b_row6_col3, #T_5c99b_row6_col4, #T_5c99b_row6_col5, #T_5c99b_row6_col6, #T_5c99b_row6_col7, #T_5c99b_row6_col8, #T_5c99b_row6_col9, #T_5c99b_row6_col10, #T_5c99b_row7_col0, #T_5c99b_row7_col1, #T_5c99b_row7_col2, #T_5c99b_row7_col3, #T_5c99b_row7_col4, #T_5c99b_row7_col5, #T_5c99b_row7_col6, #T_5c99b_row7_col7, #T_5c99b_row7_col8, #T_5c99b_row7_col9, #T_5c99b_row7_col10, #T_5c99b_row8_col0, #T_5c99b_row8_col1, #T_5c99b_row8_col2, #T_5c99b_row8_col3, #T_5c99b_row8_col4, #T_5c99b_row8_col5, #T_5c99b_row8_col6, #T_5c99b_row8_col7, #T_5c99b_row8_col8, #T_5c99b_row8_col9, #T_5c99b_row8_col10 {
#   background-color: #FFFFFF;
# }
# </style>
# <table id="T_5c99b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c99b_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_5c99b_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_5c99b_level0_col2" class="col_heading level0 col2" >Count</th>
#       <th id="T_5c99b_level0_col3" class="col_heading level0 col3" >Percent</th>
#       <th id="T_5c99b_level0_col4" class="col_heading level0 col4" >Goods</th>
#       <th id="T_5c99b_level0_col5" class="col_heading level0 col5" >Bads</th>
#       <th id="T_5c99b_level0_col6" class="col_heading level0 col6" >Bad rate</th>
#       <th id="T_5c99b_level0_col7" class="col_heading level0 col7" >WoE</th>
#       <th id="T_5c99b_level0_col8" class="col_heading level0 col8" >IV</th>
#       <th id="T_5c99b_level0_col9" class="col_heading level0 col9" >Raw score</th>
#       <th id="T_5c99b_level0_col10" class="col_heading level0 col10" >Aligned score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c99b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c99b_row0_col0" class="data row0 col0" >age</td>
#       <td id="T_5c99b_row0_col1" class="data row0 col1" >(-inf, 30.00)</td>
#       <td id="T_5c99b_row0_col2" class="data row0 col2" >1077</td>
#       <td id="T_5c99b_row0_col3" class="data row0 col3" >0.301090</td>
#       <td id="T_5c99b_row0_col4" class="data row0 col4" >1075</td>
#       <td id="T_5c99b_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_5c99b_row0_col6" class="data row0 col6" >0.001857</td>
#       <td id="T_5c99b_row0_col7" class="data row0 col7" >3.313571</td>
#       <td id="T_5c99b_row0_col8" class="data row0 col8" >1.008663</td>
#       <td id="T_5c99b_row0_col9" class="data row0 col9" >-2.949666</td>
#       <td id="T_5c99b_row0_col10" class="data row0 col10" >281</td>
#     </tr>
#     <tr>
#       <th id="T_5c99b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5c99b_row1_col0" class="data row1 col0" >age</td>
#       <td id="T_5c99b_row1_col1" class="data row1 col1" >[30.00, 60.00)</td>
#       <td id="T_5c99b_row1_col2" class="data row1 col2" >1538</td>
#       <td id="T_5c99b_row1_col3" class="data row1 col3" >0.429969</td>
#       <td id="T_5c99b_row1_col4" class="data row1 col4" >1494</td>
#       <td id="T_5c99b_row1_col5" class="data row1 col5" >44</td>
#       <td id="T_5c99b_row1_col6" class="data row1 col6" >0.028609</td>
#       <td id="T_5c99b_row1_col7" class="data row1 col7" >0.551665</td>
#       <td id="T_5c99b_row1_col8" class="data row1 col8" >0.102693</td>
#       <td id="T_5c99b_row1_col9" class="data row1 col9" >-0.491080</td>
#       <td id="T_5c99b_row1_col10" class="data row1 col10" >210</td>
#     </tr>
#     <tr>
#       <th id="T_5c99b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5c99b_row2_col0" class="data row2 col0" >age</td>
#       <td id="T_5c99b_row2_col1" class="data row2 col1" >[60.00, inf)</td>
#       <td id="T_5c99b_row2_col2" class="data row2 col2" >962</td>
#       <td id="T_5c99b_row2_col3" class="data row2 col3" >0.268940</td>
#       <td id="T_5c99b_row2_col4" class="data row2 col4" >834</td>
#       <td id="T_5c99b_row2_col5" class="data row2 col5" >128</td>
#       <td id="T_5c99b_row2_col6" class="data row2 col6" >0.133056</td>
#       <td id="T_5c99b_row2_col7" class="data row2 col7" >-1.099154</td>
#       <td id="T_5c99b_row2_col8" class="data row2 col8" >0.539195</td>
#       <td id="T_5c99b_row2_col9" class="data row2 col9" >0.978442</td>
#       <td id="T_5c99b_row2_col10" class="data row2 col10" >167</td>
#     </tr>
#     <tr>
#       <th id="T_5c99b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5c99b_row3_col0" class="data row3 col0" >bmi</td>
#       <td id="T_5c99b_row3_col1" class="data row3 col1" >Missing</td>
#       <td id="T_5c99b_row3_col2" class="data row3 col2" >147</td>
#       <td id="T_5c99b_row3_col3" class="data row3 col3" >0.041096</td>
#       <td id="T_5c99b_row3_col4" class="data row3 col4" >118</td>
#       <td id="T_5c99b_row3_col5" class="data row3 col5" >29</td>
#       <td id="T_5c99b_row3_col6" class="data row3 col6" >0.197279</td>
#       <td id="T_5c99b_row3_col7" class="data row3 col7" >-1.569969</td>
#       <td id="T_5c99b_row3_col8" class="data row3 col8" >0.207222</td>
#       <td id="T_5c99b_row3_col9" class="data row3 col9" >1.111950</td>
#       <td id="T_5c99b_row3_col10" class="data row3 col10" >163</td>
#     </tr>
#     <tr>
#       <th id="T_5c99b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5c99b_row4_col0" class="data row4 col0" >bmi</td>
#       <td id="T_5c99b_row4_col1" class="data row4 col1" >(-inf, 23.75)</td>
#       <td id="T_5c99b_row4_col2" class="data row4 col2" >910</td>
#       <td id="T_5c99b_row4_col3" class="data ro

# %% [markdown]
# <span style='color:blue'>Vemos que también entró una de las dos variables con missings: el `bmi`. De hecho, ha puesto en un grupo a parte a estos missings y esto no es casualidad:
#
# - En el autogrouping de Memento, a una variable numérica con missings **siempre se le dará un grupo aparte para estos missings**. Siempre, independientemente de su volumen (si te fijas en este caso ese grupo ni si quiera llega al 5% mínimo que se suele exigir, da igual). Esto se hace con una asignación inicial de los missings al valor -12345678, que entendemos siempre va a ser el mínimo de esa variable de forma que con un corte inmediatamente posterior a ese número nos garantizamos que estos missing están en un grupo aparte.

# %% [markdown]
# <span style='color:red'>Ok, entendido... Pero... Y si quiero juntar esos missings con otro grupo... ¿Cómo lo hago?
# - Es muy sencillo lo mostramos en la siguientes celdas. Sin embargo, no ha sido nada sencilla esta parte del código (una de la + challenging con diferencia), digamos que se basa en una idea original (o chapucera, según se mire) en la que se va remapeando el valor del missing al extremo inferior del intervalo al que se desea mover sumándole a ese extremo los primeros decimales del número $e$... Si alguno tiene curiosidad se lo explico en detalle

# %%
candidate_var, modelo_newgroups = 'bmi', modelo3
objeto = modelo_newgroups.objetos[candidate_var]

# %%
if objeto.dtype != 'O': L = [round(i, 4) for  i in list(objeto.breakpoints)]
else: L = objeto.breakpoints
print('Resultado del autogrouping de {}: {} \n'.format(candidate_var, L))
display(objeto.table)
# Out:
# Resultado del autogrouping de bmi: [-12345670.0, 23.75, 30.75, 32.05, 36.45]
#                  Group  Count   Percent  Goods  Bads  Bad rate       WoE  \
# 0              Missing    147  0.041096    118    29  0.197279 -1.569969
# 1        (-inf, 23.75)    910  0.254403    893    17  0.018681  0.988016
# 2       [23.75, 30.75)   1306  0.365110   1239    67  0.051302  -0.05599
# 3       [30.75, 32.05)    199  0.055633    181    18  0.090452 -0.665232
# 4       [32.05, 36.45)    501  0.140062    489    12  0.023952  0.734098
# 5         [36.45, inf)    514  0.143696    483    31  0.060311 -0.227328
# Totals                   3577  1.000000   3403   174  0.048644
#
#               IV
# 0       0.207222
# 1       0.162740
# 2       0.001174
# 3       0.033435
# 4       0.054860
# 5       0.008235
# Totals  0.467667

# %% [markdown]
# <span style='color:blue'>Para mantener a los missing en un grupo aparte se debe dejar el valor `-1234567.0` como primer corte y un `0 en missing_group`

# %%
bp = {'breakpoints': [-12345670.0, 20, 30, 40], 'missing_group': 0}

vector = pyk.remapeo_missing(pyk.data_convert(pyk.string_categories2(bp)).fit(modelo_newgroups.X_train[candidate_var]).x_final, bp)
breakpoints_num = pyk.breakpoints_to_num(bp['breakpoints'])
groups_names = pyk.compute_group_names(objeto.dtype, bp['breakpoints'], bp['missing_group'])
                                      
pyk.compute_table(vector, modelo_newgroups.y_train, breakpoints_num, groups_names)
# Out:
#                  Group  Count   Percent  Goods  Bads  Bad rate       WoE  \
# 0              Missing    147  0.041096    118    29  0.197279 -1.569969
# 1        (-inf, 20.00)    367  0.102600    364     3  0.008174  1.825184
# 2       [20.00, 30.00)   1718  0.480291   1642    76  0.044237   0.09958
# 3       [30.00, 40.00)   1057  0.295499   1007    50  0.047304  0.029351
# 4         [40.00, inf)    288  0.080514    272    16  0.055556 -0.140144
# Totals                   3577  1.000000   3403   174  0.048644
#
#               IV
# 0       0.207222
# 1       0.163761
# 2       0.004554
# 3       0.000251
# 4       0.001685
# Totals  0.377474

# %% [markdown]
# <span style='color:blue'>Si se quieren juntar estos missings con otro grupo existente se debe eliminar el corte de `-12345567.0` e indicar el número del grupo en `missing_group`

# %%
bp = {'breakpoints': [20, 30], 'missing_group': 3}

vector = pyk.remapeo_missing(pyk.data_convert(pyk.string_categories2(bp)).fit(modelo_newgroups.X_train[candidate_var]).x_final, bp)
breakpoints_num = pyk.breakpoints_to_num(bp['breakpoints'])
groups_names = pyk.compute_group_names(objeto.dtype, bp['breakpoints'], bp['missing_group'])
                                      
pyk.compute_table(vector, modelo_newgroups.y_train, breakpoints_num, groups_names)
# Out:
#                         Group  Count   Percent  Goods  Bads  Bad rate  \
# 0               (-inf, 20.00)    367  0.102600    364     3  0.008174
# 1              [20.00, 30.00)   1718  0.480291   1642    76  0.044237
# 2       [30.00, inf), Missing   1492  0.417109   1397    95  0.063673
# Totals                          3577  1.000000   3403   174  0.048644
#
#              WoE        IV
# 0       1.825184  0.163761
# 1        0.09958  0.004554
# 2      -0.285152  0.038626
# Totals            0.206941

# %% [markdown]
# <span style='color:blue'>Vamos a lanzar otra scorecard con esta agrupación en el `bmi`. Dado que esta es, a todas luces, peor que la automática debería salir una scorecard con menos Gini

# %%
modelo4 = pyk.autoscorecard(
    features=['age', 'bmi', 'avg_glucose_level'],
    user_breakpoints={
        'age': [30, 60],
        'bmi': {'breakpoints': [20, 30], 'missing_group': 2}
    }
).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Step 01 | Time - 0:00:00.000000 | p-value = 8.28e-27 | Gini train = 56.54% | Gini test = 54.72% ---> Feature selected: age
# Step 02 | Time - 0:00:00.000000 | p-value = 4.08e-01 | Gini train = 58.28% | Gini test = 55.94% ---> Feature selected: bmi
# Step 03 | Time - 0:00:00.000000 | p-value = 2.17e-08 | Gini train = 63.89% | Gini test = 58.96% ---> Feature selected: avg_glucose_level
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['age', 'bmi', 'avg_glucose_level']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 52.52% de KS y un 63.89% de Gini en la muestra de desarrollo
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 47.94% de KS y un 58.96% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <span style='color:blue'>Vemos como quedaría la scorecard

# %%
pyk.pretty_scorecard(modelo4, color1='red')
# Out:
# <style type="text/css">
# #T_0d2a2_row0_col0, #T_0d2a2_row0_col1, #T_0d2a2_row0_col2, #T_0d2a2_row0_col3, #T_0d2a2_row0_col4, #T_0d2a2_row0_col5, #T_0d2a2_row0_col6, #T_0d2a2_row0_col7, #T_0d2a2_row0_col8, #T_0d2a2_row0_col9, #T_0d2a2_row0_col10, #T_0d2a2_row1_col0, #T_0d2a2_row1_col1, #T_0d2a2_row1_col2, #T_0d2a2_row1_col3, #T_0d2a2_row1_col4, #T_0d2a2_row1_col5, #T_0d2a2_row1_col6, #T_0d2a2_row1_col7, #T_0d2a2_row1_col8, #T_0d2a2_row1_col9, #T_0d2a2_row1_col10, #T_0d2a2_row2_col0, #T_0d2a2_row2_col1, #T_0d2a2_row2_col2, #T_0d2a2_row2_col3, #T_0d2a2_row2_col4, #T_0d2a2_row2_col5, #T_0d2a2_row2_col6, #T_0d2a2_row2_col7, #T_0d2a2_row2_col8, #T_0d2a2_row2_col9, #T_0d2a2_row2_col10, #T_0d2a2_row6_col0, #T_0d2a2_row6_col1, #T_0d2a2_row6_col2, #T_0d2a2_row6_col3, #T_0d2a2_row6_col4, #T_0d2a2_row6_col5, #T_0d2a2_row6_col6, #T_0d2a2_row6_col7, #T_0d2a2_row6_col8, #T_0d2a2_row6_col9, #T_0d2a2_row6_col10, #T_0d2a2_row7_col0, #T_0d2a2_row7_col1, #T_0d2a2_row7_col2, #T_0d2a2_row7_col3, #T_0d2a2_row7_col4, #T_0d2a2_row7_col5, #T_0d2a2_row7_col6, #T_0d2a2_row7_col7, #T_0d2a2_row7_col8, #T_0d2a2_row7_col9, #T_0d2a2_row7_col10, #T_0d2a2_row8_col0, #T_0d2a2_row8_col1, #T_0d2a2_row8_col2, #T_0d2a2_row8_col3, #T_0d2a2_row8_col4, #T_0d2a2_row8_col5, #T_0d2a2_row8_col6, #T_0d2a2_row8_col7, #T_0d2a2_row8_col8, #T_0d2a2_row8_col9, #T_0d2a2_row8_col10, #T_0d2a2_row9_col0, #T_0d2a2_row9_col1, #T_0d2a2_row9_col2, #T_0d2a2_row9_col3, #T_0d2a2_row9_col4, #T_0d2a2_row9_col5, #T_0d2a2_row9_col6, #T_0d2a2_row9_col7, #T_0d2a2_row9_col8, #T_0d2a2_row9_col9, #T_0d2a2_row9_col10, #T_0d2a2_row10_col0, #T_0d2a2_row10_col1, #T_0d2a2_row10_col2, #T_0d2a2_row10_col3, #T_0d2a2_row10_col4, #T_0d2a2_row10_col5, #T_0d2a2_row10_col6, #T_0d2a2_row10_col7, #T_0d2a2_row10_col8, #T_0d2a2_row10_col9, #T_0d2a2_row10_col10 {
#   background-color: #FFCCCC;
# }
# #T_0d2a2_row3_col0, #T_0d2a2_row3_col1, #T_0d2a2_row3_col2, #T_0d2a2_row3_col3, #T_0d2a2_row3_col4, #T_0d2a2_row3_col5, #T_0d2a2_row3_col6, #T_0d2a2_row3_col7, #T_0d2a2_row3_col8, #T_0d2a2_row3_col9, #T_0d2a2_row3_col10, #T_0d2a2_row4_col0, #T_0d2a2_row4_col1, #T_0d2a2_row4_col2, #T_0d2a2_row4_col3, #T_0d2a2_row4_col4, #T_0d2a2_row4_col5, #T_0d2a2_row4_col6, #T_0d2a2_row4_col7, #T_0d2a2_row4_col8, #T_0d2a2_row4_col9, #T_0d2a2_row4_col10, #T_0d2a2_row5_col0, #T_0d2a2_row5_col1, #T_0d2a2_row5_col2, #T_0d2a2_row5_col3, #T_0d2a2_row5_col4, #T_0d2a2_row5_col5, #T_0d2a2_row5_col6, #T_0d2a2_row5_col7, #T_0d2a2_row5_col8, #T_0d2a2_row5_col9, #T_0d2a2_row5_col10 {
#   background-color: #FFFFFF;
# }
# </style>
# <table id="T_0d2a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d2a2_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_0d2a2_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_0d2a2_level0_col2" class="col_heading level0 col2" >Count</th>
#       <th id="T_0d2a2_level0_col3" class="col_heading level0 col3" >Percent</th>
#       <th id="T_0d2a2_level0_col4" class="col_heading level0 col4" >Goods</th>
#       <th id="T_0d2a2_level0_col5" class="col_heading level0 col5" >Bads</th>
#       <th id="T_0d2a2_level0_col6" class="col_heading level0 col6" >Bad rate</th>
#       <th id="T_0d2a2_level0_col7" class="col_heading level0 col7" >WoE</th>
#       <th id="T_0d2a2_level0_col8" class="col_heading level0 col8" >IV</th>
#       <th id="T_0d2a2_level0_col9" class="col_heading level0 col9" >Raw score</th>
#       <th id="T_0d2a2_level0_col10" class="col_heading level0 col10" >Aligned score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d2a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d2a2_row0_col0" class="data row0 col0" >age</td>
#       <td id="T_0d2a2_row0_col1" class="data row0 col1" >(-inf, 30.00)</td>
#       <td id="T_0d2a2_row0_col2" class="data row0 col2" >1077</td>
#       <td id="T_0d2a2_row0_col3" class="data row0 col3" >0.301090</td>
#       <td id="T_0d2a2_row0_col4" class="data row0 col4" >1075</td>
#       <td id="T_0d2a2_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_0d2a2_row0_col6" class="data row0 col6" >0.001857</td>
#       <td id="T_0d2a2_row0_col7" class="data row0 col7" >3.313571</td>
#       <td id="T_0d2a2_row0_col8" class="data row0 col8" >1.008663</td>
#       <td id="T_0d2a2_row0_col9" class="data row0 col9" >-3.001183</td>
#       <td id="T_0d2a2_row0_col10" class="data row0 col10" >282</td>
#     </tr>
#     <tr>
#       <th id="T_0d2a2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d2a2_row1_col0" class="data row1 col0" >age</td>
#       <td id="T_0d2a2_row1_col1" class="data row1 col1" >[30.00, 60.00)</td>
#       <td id="T_0d2a2_row1_col2" class="data row1 col2" >1538</td>
#       <td id="T_0d2a2_row1_col3" class="data row1 col3" >0.429969</td>
#       <td id="T_0d2a2_row1_col4" class="data row1 col4" >1494</td>
#       <td id="T_0d2a2_row1_col5" class="data row1 col5" >44</td>
#       <td id="T_0d2a2_row1_col6" class="data row1 col6" >0.028609</td>
#       <td id="T_0d2a2_row1_col7" class="data row1 col7" >0.551665</td>
#       <td id="T_0d2a2_row1_col8" class="data row1 col8" >0.102693</td>
#       <td id="T_0d2a2_row1_col9" class="data row1 col9" >-0.499657</td>
#       <td id="T_0d2a2_row1_col10" class="data row1 col10" >210</td>
#     </tr>
#     <tr>
#       <th id="T_0d2a2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d2a2_row2_col0" class="data row2 col0" >age</td>
#       <td id="T_0d2a2_row2_col1" class="data row2 col1" >[60.00, inf)</td>
#       <td id="T_0d2a2_row2_col2" class="data row2 col2" >962</td>
#       <td id="T_0d2a2_row2_col3" class="data row2 col3" >0.268940</td>
#       <td id="T_0d2a2_row2_col4" class="data row2 col4" >834</td>
#       <td id="T_0d2a2_row2_col5" class="data row2 col5" >128</td>
#       <td id="T_0d2a2_row2_col6" class="data row2 col6" >0.133056</td>
#       <td id="T_0d2a2_row2_col7" class="data row2 col7" >-1.099154</td>
#       <td id="T_0d2a2_row2_col8" class="data row2 col8" >0.539195</td>
#       <td id="T_0d2a2_row2_col9" class="data row2 col9" >0.995531</td>
#       <td id="T_0d2a2_row2_col10" class="data row2 col10" >167</td>
#     </tr>
#     <tr>
#       <th id="T_0d2a2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d2a2_row3_col0" class="data row3 col0" >bmi</td>
#       <td id="T_0d2a2_row3_col1" class="data row3 col1" >(-inf, 20.00)</td>
#       <td id="T_0d2a2_row3_col2" class="data row3 col2" >367</td>
#       <td id="T_0d2a2_row3_col3" class="data row3 col3" >0.102600</td>
#       <td id="T_0d2a2_row3_col4" class="data row3 col4" >364</td>
#       <td id="T_0d2a2_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_0d2a2_row3_col6" class="data row3 col6" >0.008174</td>
#       <td id="T_0d2a2_row3_col7" class="data row3 col7" >1.825184</td>
#       <td id="T_0d2a2_row3_col8" class="data row3 col8" >0.163761</td>
#       <td id="T_0d2a2_row3_col9" class="data row3 col9" >-0.507091</td>
#       <td id="T_0d2a2_row3_col10" class="data row3 col10" >210</td>
#     </tr>
#     <tr>
#       <th id="T_0d2a2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d2a2_row4_col0" class="data row4 col0" >bmi</td>
#       <td id="T_0d2a2_row4_col1" class="data row4 col1" >[20.00, 30.00), Missing</td>
#       <td id="T_0d2a2_row4_col2" class="data row4 col2" >1865</td>
#       <td id="T_0d2a2_row4_col3" class="data row4 col3" >0.521387</td>
#       <td id="T_0d2a2_row4_col4" class="data row4 col4" >1760</td>
#       <td id="T_0d2a2_row4_col5" class="data row4 col5" >105</td>
#       <td id="T_0d2a2_row4_col6" class="data row4 col6" >0.056300</td>
#       <td id="T_0d2a2_row4_col7" class="data row4 col7" >-0.154249</td>
#       <td id="T_0d2a2_row4_col8" class="data row4 col8" >0.013305</td>
#       <td id="T_0d2a2_row4_col9" class="data row4 col9" >0.042855</td>
#       <td id="T_0d2a2_row4_col10" class="data row4 col10" >194</td>
#     </tr>
#     <tr>
#       <th id="T_0d2a2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0d2a2_row5_col0" class="data row5 col0" >bmi</td>
#       <td

# %% [markdown]
# <span style='color:red'>¿Y si la variable que tuviera missings fuese de tipo `texto`?!
# - Entonces sería mucho más fácil: en una variable categórica el missing se trata como una categoría más, no hay distinción con el resto

# %% [markdown]
# <span style='color:blue'>Vemos un ejemplo añadiendo como feature la variable de tipo texto `work_type`

# %%
modelo5 = pyk.autoscorecard(
    features=['age', 'bmi', 'avg_glucose_level', 'work_type'],
    user_breakpoints={
        'age': [30, 60],
        'bmi': {'breakpoints': [20, 30], 'missing_group': 2}
    }).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Step 01 | Time - 0:00:00.000000 | p-value = 8.28e-27 | Gini train = 56.54% | Gini test = 54.72% ---> Feature selected: age
# Step 02 | Time - 0:00:00.000000 | p-value = 4.08e-01 | Gini train = 58.28% | Gini test = 55.94% ---> Feature selected: bmi
# Step 03 | Time - 0:00:00.000000 | p-value = 2.17e-08 | Gini train = 63.89% | Gini test = 58.96% ---> Feature selected: avg_glucose_level
# Step 04 | Time - 0:00:00.000000 | p-value = 3.11e-01 | Gini train = 63.45% | Gini test = 57.89% ---> Feature selected: work_type
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['age', 'bmi', 'avg_glucose_level', 'work_type']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 52.52% de KS y un 63.45% de Gini en la muestra de desarrollo
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 49.14% de KS y un 57.89% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
pyk.pretty_scorecard(modelo5, color1='yellow')
# Out:
# <style type="text/css">
# #T_0b9ac_row0_col0, #T_0b9ac_row0_col1, #T_0b9ac_row0_col2, #T_0b9ac_row0_col3, #T_0b9ac_row0_col4, #T_0b9ac_row0_col5, #T_0b9ac_row0_col6, #T_0b9ac_row0_col7, #T_0b9ac_row0_col8, #T_0b9ac_row0_col9, #T_0b9ac_row0_col10, #T_0b9ac_row1_col0, #T_0b9ac_row1_col1, #T_0b9ac_row1_col2, #T_0b9ac_row1_col3, #T_0b9ac_row1_col4, #T_0b9ac_row1_col5, #T_0b9ac_row1_col6, #T_0b9ac_row1_col7, #T_0b9ac_row1_col8, #T_0b9ac_row1_col9, #T_0b9ac_row1_col10, #T_0b9ac_row2_col0, #T_0b9ac_row2_col1, #T_0b9ac_row2_col2, #T_0b9ac_row2_col3, #T_0b9ac_row2_col4, #T_0b9ac_row2_col5, #T_0b9ac_row2_col6, #T_0b9ac_row2_col7, #T_0b9ac_row2_col8, #T_0b9ac_row2_col9, #T_0b9ac_row2_col10, #T_0b9ac_row6_col0, #T_0b9ac_row6_col1, #T_0b9ac_row6_col2, #T_0b9ac_row6_col3, #T_0b9ac_row6_col4, #T_0b9ac_row6_col5, #T_0b9ac_row6_col6, #T_0b9ac_row6_col7, #T_0b9ac_row6_col8, #T_0b9ac_row6_col9, #T_0b9ac_row6_col10, #T_0b9ac_row7_col0, #T_0b9ac_row7_col1, #T_0b9ac_row7_col2, #T_0b9ac_row7_col3, #T_0b9ac_row7_col4, #T_0b9ac_row7_col5, #T_0b9ac_row7_col6, #T_0b9ac_row7_col7, #T_0b9ac_row7_col8, #T_0b9ac_row7_col9, #T_0b9ac_row7_col10, #T_0b9ac_row8_col0, #T_0b9ac_row8_col1, #T_0b9ac_row8_col2, #T_0b9ac_row8_col3, #T_0b9ac_row8_col4, #T_0b9ac_row8_col5, #T_0b9ac_row8_col6, #T_0b9ac_row8_col7, #T_0b9ac_row8_col8, #T_0b9ac_row8_col9, #T_0b9ac_row8_col10, #T_0b9ac_row9_col0, #T_0b9ac_row9_col1, #T_0b9ac_row9_col2, #T_0b9ac_row9_col3, #T_0b9ac_row9_col4, #T_0b9ac_row9_col5, #T_0b9ac_row9_col6, #T_0b9ac_row9_col7, #T_0b9ac_row9_col8, #T_0b9ac_row9_col9, #T_0b9ac_row9_col10, #T_0b9ac_row10_col0, #T_0b9ac_row10_col1, #T_0b9ac_row10_col2, #T_0b9ac_row10_col3, #T_0b9ac_row10_col4, #T_0b9ac_row10_col5, #T_0b9ac_row10_col6, #T_0b9ac_row10_col7, #T_0b9ac_row10_col8, #T_0b9ac_row10_col9, #T_0b9ac_row10_col10 {
#   background-color: #FFFFCC;
# }
# #T_0b9ac_row3_col0, #T_0b9ac_row3_col1, #T_0b9ac_row3_col2, #T_0b9ac_row3_col3, #T_0b9ac_row3_col4, #T_0b9ac_row3_col5, #T_0b9ac_row3_col6, #T_0b9ac_row3_col7, #T_0b9ac_row3_col8, #T_0b9ac_row3_col9, #T_0b9ac_row3_col10, #T_0b9ac_row4_col0, #T_0b9ac_row4_col1, #T_0b9ac_row4_col2, #T_0b9ac_row4_col3, #T_0b9ac_row4_col4, #T_0b9ac_row4_col5, #T_0b9ac_row4_col6, #T_0b9ac_row4_col7, #T_0b9ac_row4_col8, #T_0b9ac_row4_col9, #T_0b9ac_row4_col10, #T_0b9ac_row5_col0, #T_0b9ac_row5_col1, #T_0b9ac_row5_col2, #T_0b9ac_row5_col3, #T_0b9ac_row5_col4, #T_0b9ac_row5_col5, #T_0b9ac_row5_col6, #T_0b9ac_row5_col7, #T_0b9ac_row5_col8, #T_0b9ac_row5_col9, #T_0b9ac_row5_col10, #T_0b9ac_row11_col0, #T_0b9ac_row11_col1, #T_0b9ac_row11_col2, #T_0b9ac_row11_col3, #T_0b9ac_row11_col4, #T_0b9ac_row11_col5, #T_0b9ac_row11_col6, #T_0b9ac_row11_col7, #T_0b9ac_row11_col8, #T_0b9ac_row11_col9, #T_0b9ac_row11_col10, #T_0b9ac_row12_col0, #T_0b9ac_row12_col1, #T_0b9ac_row12_col2, #T_0b9ac_row12_col3, #T_0b9ac_row12_col4, #T_0b9ac_row12_col5, #T_0b9ac_row12_col6, #T_0b9ac_row12_col7, #T_0b9ac_row12_col8, #T_0b9ac_row12_col9, #T_0b9ac_row12_col10, #T_0b9ac_row13_col0, #T_0b9ac_row13_col1, #T_0b9ac_row13_col2, #T_0b9ac_row13_col3, #T_0b9ac_row13_col4, #T_0b9ac_row13_col5, #T_0b9ac_row13_col6, #T_0b9ac_row13_col7, #T_0b9ac_row13_col8, #T_0b9ac_row13_col9, #T_0b9ac_row13_col10, #T_0b9ac_row14_col0, #T_0b9ac_row14_col1, #T_0b9ac_row14_col2, #T_0b9ac_row14_col3, #T_0b9ac_row14_col4, #T_0b9ac_row14_col5, #T_0b9ac_row14_col6, #T_0b9ac_row14_col7, #T_0b9ac_row14_col8, #T_0b9ac_row14_col9, #T_0b9ac_row14_col10 {
#   background-color: #FFFFFF;
# }
# </style>
# <table id="T_0b9ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b9ac_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_0b9ac_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_0b9ac_level0_col2" class="col_heading level0 col2" >Count</th>
#       <th id="T_0b9ac_level0_col3" class="col_heading level0 col3" >Percent</th>
#       <th id="T_0b9ac_level0_col4" class="col_heading level0 col4" >Goods</th>
#       <th id="T_0b9ac_level0_col5" class="col_heading level0 col5" >Bads</th>
#       <th id="T_0b9ac_level0_col6" class="col_heading level0 col6" >Bad rate</th>
#       <th id="T_0b9ac_level0_col7" class="col_heading level0 col7" >WoE</th>
#       <th id="T_0b9ac_level0_col8" class="col_heading level0 col8" >IV</th>
#       <th id="T_0b9ac_level0_col9" class="col_heading level0 col9" >Raw score</th>
#       <th id="T_0b9ac_level0_col10" class="col_heading level0 col10" >Aligned score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b9ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b9ac_row0_col0" class="data row0 col0" >age</td>
#       <td id="T_0b9ac_row0_col1" class="data row0 col1" >(-inf, 30.00)</td>
#       <td id="T_0b9ac_row0_col2" class="data row0 col2" >1077</td>
#       <td id="T_0b9ac_row0_col3" class="data row0 col3" >0.301090</td>
#       <td id="T_0b9ac_row0_col4" class="data row0 col4" >1075</td>
#       <td id="T_0b9ac_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_0b9ac_row0_col6" class="data row0 col6" >0.001857</td>
#       <td id="T_0b9ac_row0_col7" class="data row0 col7" >3.313571</td>
#       <td id="T_0b9ac_row0_col8" class="data row0 col8" >1.008663</td>
#       <td id="T_0b9ac_row0_col9" class="data row0 col9" >-3.120752</td>
#       <td id="T_0b9ac_row0_col10" class="data row0 col10" >236</td>
#     </tr>
#     <tr>
#       <th id="T_0b9ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0b9ac_row1_col0" class="data row1 col0" >age</td>
#       <td id="T_0b9ac_row1_col1" class="data row1 col1" >[30.00, 60.00)</td>
#       <td id="T_0b9ac_row1_col2" class="data row1 col2" >1538</td>
#       <td id="T_0b9ac_row1_col3" class="data row1 col3" >0.429969</td>
#       <td id="T_0b9ac_row1_col4" class="data row1 col4" >1494</td>
#       <td id="T_0b9ac_row1_col5" class="data row1 col5" >44</td>
#       <td id="T_0b9ac_row1_col6" class="data row1 col6" >0.028609</td>
#       <td id="T_0b9ac_row1_col7" class="data row1 col7" >0.551665</td>
#       <td id="T_0b9ac_row1_col8" class="data row1 col8" >0.102693</td>
#       <td id="T_0b9ac_row1_col9" class="data row1 col9" >-0.519563</td>
#       <td id="T_0b9ac_row1_col10" class="data row1 col10" >161</td>
#     </tr>
#     <tr>
#       <th id="T_0b9ac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0b9ac_row2_col0" class="data row2 col0" >age</td>
#       <td id="T_0b9ac_row2_col1" class="data row2 col1" >[60.00, inf)</td>
#       <td id="T_0b9ac_row2_col2" class="data row2 col2" >962</td>
#       <td id="T_0b9ac_row2_col3" class="data row2 col3" >0.268940</td>
#       <td id="T_0b9ac_row2_col4" class="data row2 col4" >834</td>
#       <td id="T_0b9ac_row2_col5" class="data row2 col5" >128</td>
#       <td id="T_0b9ac_row2_col6" class="data row2 col6" >0.133056</td>
#       <td id="T_0b9ac_row2_col7" class="data row2 col7" >-1.099154</td>
#       <td id="T_0b9ac_row2_col8" class="data row2 col8" >0.539195</td>
#       <td id="T_0b9ac_row2_col9" class="data row2 col9" >1.035194</td>
#       <td id="T_0b9ac_row2_col10" class="data row2 col10" >117</td>
#     </tr>
#     <tr>
#       <th id="T_0b9ac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0b9ac_row3_col0" class="data row3 col0" >bmi</td>
#       <td id="T_0b9ac_row3_col1" class="data row3 col1" >(-inf, 20.00)</td>
#       <td id="T_0b9ac_row3_col2" class="data row3 col2" >367</td>
#       <td id="T_0b9ac_row3_col3" class="data row3 col3" >0.102600</td>
#       <td id="T_0b9ac_row3_col4" class="data row3 col4" >364</td>
#       <td id="T_0b9ac_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_0b9ac_row3_col6" class="data row3 col6" >0.008174</td>
#       <td id="T_0b9ac_row3_col7" class="data row3 col7" >1.825184</td>
#       <td id="T_0b9ac_row3_col8" class="data row3 col8" >0.163761</td>
#       <td id="T_0b9ac_row3_col9" class="data row3 col9" >-0.632970</td>
#       <td id="T_0b9ac_row3_col10" class="data row3 col10" >165</td>
#     </tr>
#     <tr>
#       <th id="T_0b9ac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0b

# %% [markdown]
# <span style='color:blue'>La agrupación se hace igual que al principio, independientemente de que la variable tenga missings o no

# %%
candidate_var, modelo_newgroups = 'work_type', modelo5
objeto = modelo_newgroups.objetos[candidate_var]

# %%
if objeto.dtype != 'O': L = [round(i, 4) for  i in list(objeto.breakpoints)]
else: L = objeto.breakpoints
print('Resultado del autogrouping de {}: {} \n'.format(candidate_var, L))
display(objeto.table)
# Out:
# Resultado del autogrouping de work_type: [['Missing'], ['Private'], ['Govt_job'], ['children', 'Never_worked']]
#                            Group  Count   Percent  Goods  Bads  Bad rate  \
# 0                      [Missing]    572  0.159911    530    42  0.073427
# 1                      [Private]   2025  0.566117   1915   110  0.054321
# 2                     [Govt_job]    467  0.130556    447    20  0.042827
# 3       [children, Never_worked]    513  0.143416    511     2  0.003899
# Totals                             3577  1.000000   3403   174  0.048644
#
#              WoE        IV
# 0       -0.43815  0.037521
# 1      -0.116365  0.008081
# 2       0.133469  0.002191
# 3       2.569865  0.356356
# Totals            0.404149

# %%
bp = [['Private', 'Govt_job'], ['Missing', 'Never_worked'], ['children']]

vector = pyk.data_convert(pyk.string_categories2(bp)).fit(modelo_newgroups.X_train[candidate_var]).x_final
breakpoints_num = pyk.breakpoints_to_num(bp)
groups_names = pyk.compute_group_names(objeto.dtype, bp)
                                      
pyk.compute_table(vector, modelo_newgroups.y_train, breakpoints_num, groups_names)
# Out:
#                           Group  Count   Percent  Goods  Bads  Bad rate  \
# 0           [Private, Govt_job]   2492  0.696673   2362   130  0.052167
# 1       [Missing, Never_worked]    590  0.164943    548    42  0.071186
# 2                    [children]    495  0.138384    493     2  0.004040
# Totals                            3577  1.000000   3403   174  0.048644
#
#              WoE        IV
# 0      -0.073628  0.003905
# 1      -0.404752  0.032520
# 2       2.534005  0.337980
# Totals            0.374405

# %% [markdown]
# <span style='color:blue'>Lanzamos la última scorecard con la variable de tipo texto reagrupada

# %%
modelo6 = pyk.autoscorecard(
    features=['age', 'bmi', 'avg_glucose_level', 'work_type'],
    user_breakpoints={
        'age': [30, 60],
        'bmi': {'breakpoints': [20, 30], 'missing_group': 2},
        'work_type': [['Private', 'Govt_job'], ['Missing', 'Never_worked'], ['children']]
    }).fit(X, y)
# Out:
# Particionado 70-30 estratificado en el target terminado.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Autogrouping terminado. Máximo número de buckets = 5. Mínimo porcentaje por bucket = 0.05
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Step 01 | Time - 0:00:00.000000 | p-value = 8.28e-27 | Gini train = 56.54% | Gini test = 54.72% ---> Feature selected: age
# Step 02 | Time - 0:00:00.000000 | p-value = 4.08e-01 | Gini train = 58.28% | Gini test = 55.94% ---> Feature selected: bmi
# Step 03 | Time - 0:00:00.000000 | p-value = 2.17e-08 | Gini train = 63.89% | Gini test = 58.96% ---> Feature selected: avg_glucose_level
# Step 04 | Time - 0:00:00.000000 | p-value = 7.67e-02 | Gini train = 63.96% | Gini test = 58.05% ---> Feature selected: work_type
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Selección terminada: ['age', 'bmi', 'avg_glucose_level', 'work_type']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 52.58% de KS y un 63.96% de Gini en la muestra de desarrollo
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# El modelo tiene un 48.66% de KS y un 58.05% de Gini en la muestra de validación
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
pyk.pretty_scorecard(modelo6, color1='pink')
# Out:
# <style type="text/css">
# #T_7e9b2_row0_col0, #T_7e9b2_row0_col1, #T_7e9b2_row0_col2, #T_7e9b2_row0_col3, #T_7e9b2_row0_col4, #T_7e9b2_row0_col5, #T_7e9b2_row0_col6, #T_7e9b2_row0_col7, #T_7e9b2_row0_col8, #T_7e9b2_row0_col9, #T_7e9b2_row0_col10, #T_7e9b2_row1_col0, #T_7e9b2_row1_col1, #T_7e9b2_row1_col2, #T_7e9b2_row1_col3, #T_7e9b2_row1_col4, #T_7e9b2_row1_col5, #T_7e9b2_row1_col6, #T_7e9b2_row1_col7, #T_7e9b2_row1_col8, #T_7e9b2_row1_col9, #T_7e9b2_row1_col10, #T_7e9b2_row2_col0, #T_7e9b2_row2_col1, #T_7e9b2_row2_col2, #T_7e9b2_row2_col3, #T_7e9b2_row2_col4, #T_7e9b2_row2_col5, #T_7e9b2_row2_col6, #T_7e9b2_row2_col7, #T_7e9b2_row2_col8, #T_7e9b2_row2_col9, #T_7e9b2_row2_col10, #T_7e9b2_row6_col0, #T_7e9b2_row6_col1, #T_7e9b2_row6_col2, #T_7e9b2_row6_col3, #T_7e9b2_row6_col4, #T_7e9b2_row6_col5, #T_7e9b2_row6_col6, #T_7e9b2_row6_col7, #T_7e9b2_row6_col8, #T_7e9b2_row6_col9, #T_7e9b2_row6_col10, #T_7e9b2_row7_col0, #T_7e9b2_row7_col1, #T_7e9b2_row7_col2, #T_7e9b2_row7_col3, #T_7e9b2_row7_col4, #T_7e9b2_row7_col5, #T_7e9b2_row7_col6, #T_7e9b2_row7_col7, #T_7e9b2_row7_col8, #T_7e9b2_row7_col9, #T_7e9b2_row7_col10, #T_7e9b2_row8_col0, #T_7e9b2_row8_col1, #T_7e9b2_row8_col2, #T_7e9b2_row8_col3, #T_7e9b2_row8_col4, #T_7e9b2_row8_col5, #T_7e9b2_row8_col6, #T_7e9b2_row8_col7, #T_7e9b2_row8_col8, #T_7e9b2_row8_col9, #T_7e9b2_row8_col10, #T_7e9b2_row9_col0, #T_7e9b2_row9_col1, #T_7e9b2_row9_col2, #T_7e9b2_row9_col3, #T_7e9b2_row9_col4, #T_7e9b2_row9_col5, #T_7e9b2_row9_col6, #T_7e9b2_row9_col7, #T_7e9b2_row9_col8, #T_7e9b2_row9_col9, #T_7e9b2_row9_col10, #T_7e9b2_row10_col0, #T_7e9b2_row10_col1, #T_7e9b2_row10_col2, #T_7e9b2_row10_col3, #T_7e9b2_row10_col4, #T_7e9b2_row10_col5, #T_7e9b2_row10_col6, #T_7e9b2_row10_col7, #T_7e9b2_row10_col8, #T_7e9b2_row10_col9, #T_7e9b2_row10_col10 {
#   background-color: #FFCCFF;
# }
# #T_7e9b2_row3_col0, #T_7e9b2_row3_col1, #T_7e9b2_row3_col2, #T_7e9b2_row3_col3, #T_7e9b2_row3_col4, #T_7e9b2_row3_col5, #T_7e9b2_row3_col6, #T_7e9b2_row3_col7, #T_7e9b2_row3_col8, #T_7e9b2_row3_col9, #T_7e9b2_row3_col10, #T_7e9b2_row4_col0, #T_7e9b2_row4_col1, #T_7e9b2_row4_col2, #T_7e9b2_row4_col3, #T_7e9b2_row4_col4, #T_7e9b2_row4_col5, #T_7e9b2_row4_col6, #T_7e9b2_row4_col7, #T_7e9b2_row4_col8, #T_7e9b2_row4_col9, #T_7e9b2_row4_col10, #T_7e9b2_row5_col0, #T_7e9b2_row5_col1, #T_7e9b2_row5_col2, #T_7e9b2_row5_col3, #T_7e9b2_row5_col4, #T_7e9b2_row5_col5, #T_7e9b2_row5_col6, #T_7e9b2_row5_col7, #T_7e9b2_row5_col8, #T_7e9b2_row5_col9, #T_7e9b2_row5_col10, #T_7e9b2_row11_col0, #T_7e9b2_row11_col1, #T_7e9b2_row11_col2, #T_7e9b2_row11_col3, #T_7e9b2_row11_col4, #T_7e9b2_row11_col5, #T_7e9b2_row11_col6, #T_7e9b2_row11_col7, #T_7e9b2_row11_col8, #T_7e9b2_row11_col9, #T_7e9b2_row11_col10, #T_7e9b2_row12_col0, #T_7e9b2_row12_col1, #T_7e9b2_row12_col2, #T_7e9b2_row12_col3, #T_7e9b2_row12_col4, #T_7e9b2_row12_col5, #T_7e9b2_row12_col6, #T_7e9b2_row12_col7, #T_7e9b2_row12_col8, #T_7e9b2_row12_col9, #T_7e9b2_row12_col10, #T_7e9b2_row13_col0, #T_7e9b2_row13_col1, #T_7e9b2_row13_col2, #T_7e9b2_row13_col3, #T_7e9b2_row13_col4, #T_7e9b2_row13_col5, #T_7e9b2_row13_col6, #T_7e9b2_row13_col7, #T_7e9b2_row13_col8, #T_7e9b2_row13_col9, #T_7e9b2_row13_col10 {
#   background-color: #FFFFFF;
# }
# </style>
# <table id="T_7e9b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e9b2_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_7e9b2_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_7e9b2_level0_col2" class="col_heading level0 col2" >Count</th>
#       <th id="T_7e9b2_level0_col3" class="col_heading level0 col3" >Percent</th>
#       <th id="T_7e9b2_level0_col4" class="col_heading level0 col4" >Goods</th>
#       <th id="T_7e9b2_level0_col5" class="col_heading level0 col5" >Bads</th>
#       <th id="T_7e9b2_level0_col6" class="col_heading level0 col6" >Bad rate</th>
#       <th id="T_7e9b2_level0_col7" class="col_heading level0 col7" >WoE</th>
#       <th id="T_7e9b2_level0_col8" class="col_heading level0 col8" >IV</th>
#       <th id="T_7e9b2_level0_col9" class="col_heading level0 col9" >Raw score</th>
#       <th id="T_7e9b2_level0_col10" class="col_heading level0 col10" >Aligned score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e9b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e9b2_row0_col0" class="data row0 col0" >age</td>
#       <td id="T_7e9b2_row0_col1" class="data row0 col1" >(-inf, 30.00)</td>
#       <td id="T_7e9b2_row0_col2" class="data row0 col2" >1077</td>
#       <td id="T_7e9b2_row0_col3" class="data row0 col3" >0.301090</td>
#       <td id="T_7e9b2_row0_col4" class="data row0 col4" >1075</td>
#       <td id="T_7e9b2_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_7e9b2_row0_col6" class="data row0 col6" >0.001857</td>
#       <td id="T_7e9b2_row0_col7" class="data row0 col7" >3.313571</td>
#       <td id="T_7e9b2_row0_col8" class="data row0 col8" >1.008663</td>
#       <td id="T_7e9b2_row0_col9" class="data row0 col9" >-3.230911</td>
#       <td id="T_7e9b2_row0_col10" class="data row0 col10" >240</td>
#     </tr>
#     <tr>
#       <th id="T_7e9b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e9b2_row1_col0" class="data row1 col0" >age</td>
#       <td id="T_7e9b2_row1_col1" class="data row1 col1" >[30.00, 60.00)</td>
#       <td id="T_7e9b2_row1_col2" class="data row1 col2" >1538</td>
#       <td id="T_7e9b2_row1_col3" class="data row1 col3" >0.429969</td>
#       <td id="T_7e9b2_row1_col4" class="data row1 col4" >1494</td>
#       <td id="T_7e9b2_row1_col5" class="data row1 col5" >44</td>
#       <td id="T_7e9b2_row1_col6" class="data row1 col6" >0.028609</td>
#       <td id="T_7e9b2_row1_col7" class="data row1 col7" >0.551665</td>
#       <td id="T_7e9b2_row1_col8" class="data row1 col8" >0.102693</td>
#       <td id="T_7e9b2_row1_col9" class="data row1 col9" >-0.537903</td>
#       <td id="T_7e9b2_row1_col10" class="data row1 col10" >162</td>
#     </tr>
#     <tr>
#       <th id="T_7e9b2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e9b2_row2_col0" class="data row2 col0" >age</td>
#       <td id="T_7e9b2_row2_col1" class="data row2 col1" >[60.00, inf)</td>
#       <td id="T_7e9b2_row2_col2" class="data row2 col2" >962</td>
#       <td id="T_7e9b2_row2_col3" class="data row2 col3" >0.268940</td>
#       <td id="T_7e9b2_row2_col4" class="data row2 col4" >834</td>
#       <td id="T_7e9b2_row2_col5" class="data row2 col5" >128</td>
#       <td id="T_7e9b2_row2_col6" class="data row2 col6" >0.133056</td>
#       <td id="T_7e9b2_row2_col7" class="data row2 col7" >-1.099154</td>
#       <td id="T_7e9b2_row2_col8" class="data row2 col8" >0.539195</td>
#       <td id="T_7e9b2_row2_col9" class="data row2 col9" >1.071735</td>
#       <td id="T_7e9b2_row2_col10" class="data row2 col10" >115</td>
#     </tr>
#     <tr>
#       <th id="T_7e9b2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e9b2_row3_col0" class="data row3 col0" >bmi</td>
#       <td id="T_7e9b2_row3_col1" class="data row3 col1" >(-inf, 20.00)</td>
#       <td id="T_7e9b2_row3_col2" class="data row3 col2" >367</td>
#       <td id="T_7e9b2_row3_col3" class="data row3 col3" >0.102600</td>
#       <td id="T_7e9b2_row3_col4" class="data row3 col4" >364</td>
#       <td id="T_7e9b2_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_7e9b2_row3_col6" class="data row3 col6" >0.008174</td>
#       <td id="T_7e9b2_row3_col7" class="data row3 col7" >1.825184</td>
#       <td id="T_7e9b2_row3_col8" class="data row3 col8" >0.163761</td>
#       <td id="T_7e9b2_row3_col9" class="data row3 col9" >-0.762649</td>
#       <td id="T_7e9b2_row3_col10" class="data row3 col10" >168</td>
#     </tr>
#     <tr>
#       <th id="T_7e9b2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7e9b2_row4_col0" class="data row4 col0" >bmi</td>
#       <td id="T_7e9b2_row4_col1" class="data row4 col1" >[20.00, 30.00), Missing</td>
#       <td id="T_7e9b2_row4_col2" class="data row4 col2" >1865</td>
#       <td id="T_7e9b2_row4_col3
